# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.rc('figure', figsize= (10, 5))

# %%
dados = pd.read_csv('dados/list_of_countries_by_carbon_dioxide_emissions.csv')

# %%
dados.head()
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                            NaN                      1990.000    2005.000
# 1                          World                     22674.116   30049.809
# 2  World  International Aviation                       258.941     422.777
# 3  World  International Shipping                       371.804     572.169
# 4                    Afghanistan                         2.546       1.063
#
#    Unnamed: 3 Fossil CO2 emissions                Unnamed: 5  \
# 0    2017.000     2017(% of world)  2017 vs 1990: change (%)
# 1   37077.404              100.00%                    63.50%
# 2     543.381                1.47%                   109.80%
# 3     677.248                1.83%                    82.20%
# 4      11.422                0.03%                   348.60%
#
#     2017  Fossil CO2 emissions                Unnamed: 7  \
# 0  Per land area(t CO2/km2/yr)  Per capita(t CO2/cap/yr)
# 1                           73                       4.9
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                           18                       0.3
#
#      2018 CO2 emissions            Unnamed: 9
# 0  Total including LUCF  Total excluding LUCF
# 1              36431.11              35247.21
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                  7.59                  7.44

# %%
dados_ = dados.rename(columns = {'Fossil CO2 emissions(Mt CO2)': 'Fossil CO2 emissions(Mt CO2) 1990', 'Unnamed: 2': '2005',
                              'Unnamed: 3': '2017', 'Fossil CO2 emissions': 'Fossil CO2 emissions (2017(% of world))', 
                              'Unnamed: 5': '2017 vs 1990: change (%)', '2017 Fossil CO2 emissions': '2017 Fossil CO2 emissions (Per land area(t CO2/km2/yr))',
                              'Unnamed: 7': 'Per capita(t CO2/cap/yr)', '2018 CO2 emissions': '2018 CO2 emissions (Total including LUCF)',
                              'Unnamed: 9': 'Total excluding LUCF'})

# %%
dados_.head()
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2) 1990  \
# 0                            NaN                           1990.000
# 1                          World                          22674.116
# 2  World  International Aviation                            258.941
# 3  World  International Shipping                            371.804
# 4                    Afghanistan                              2.546
#
#         2005       2017 Fossil CO2 emissions (2017(% of world))  \
# 0   2005.000   2017.000                        2017(% of world)
# 1  30049.809  37077.404                                 100.00%
# 2    422.777    543.381                                   1.47%
# 3    572.169    677.248                                   1.83%
# 4      1.063     11.422                                   0.03%
#
#    2017 vs 1990: change (%)   2017  Fossil CO2 emissions  \
# 0  2017 vs 1990: change (%)  Per land area(t CO2/km2/yr)
# 1                    63.50%                           73
# 2                   109.80%                          NaN
# 3                    82.20%                          NaN
# 4                   348.60%                           18
#
#    Per capita(t CO2/cap/yr) 2018 CO2 emissions (Total including LUCF)  \
# 0  Per capita(t CO2/cap/yr)                      Total including LUCF
# 1                       4.9                                  36431.11
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                       0.3                                      7.59
#
#    Total excluding LUCF
# 0  Total excluding LUCF
# 1              35247.21
# 2                   NaN
# 3                   NaN
# 4                  7.44

# %%
dados_.drop(0, axis=0, inplace=True)

# %%
dados_
# Out:
#                            Country  Fossil CO2 emissions(Mt CO2) 1990  \
# 1                            World                          22674.116
# 2    World  International Aviation                            258.941
# 3    World  International Shipping                            371.804
# 4                      Afghanistan                              2.546
# 5                          Albania                              6.583
# ..                             ...                                ...
# 208                        Vietnam                             20.182
# 209                 Western Sahara                              0.144
# 210                          Yemen                              6.887
# 211                         Zambia                              2.955
# 212                       Zimbabwe                             17.178
#
#           2005       2017 Fossil CO2 emissions (2017(% of world))  \
# 1    30049.809  37077.404                                 100.00%
# 2      422.777    543.381                                   1.47%
# 3      572.169    677.248                                   1.83%
# 4        1.063     11.422                                   0.03%
# 5        4.196      5.026                                   0.01%
# ..         ...        ...                                     ...
# 208     99.231    218.729                                   0.59%
# 209      0.227      0.276                                   0.00%
# 210     21.768     12.503                                   0.03%
# 211      2.457      4.967                                   0.01%
# 212     11.388     12.087                                   0.03%
#
#     2017 vs 1990: change (%) 2017  Fossil CO2 emissions  \
# 1                     63.50%                         73
# 2                    109.80%                        NaN
# 3                     82.20%                        NaN
# 4                    348.60%                         18
# 5                    -23.70%                        175
# ..                       ...                        ...
# 208                  983.80%                        660
# 209                   91.70%                          1
# 210                   81.50%                         24
# 211                   68.10%                          7
# 212                  -29.60%                         31
#
#     Per capita(t CO2/cap/yr) 2018 CO2 emissions (Total including LUCF)  \
# 1                        4.9                                  36431.11
# 2                        NaN                                       NaN
# 3                        NaN                                       NaN
# 4                        0.3                                      7.59
# 5                        1.7                                      5.32
# ..                       ...                                       ...
# 208                      2.3                                    245.36
# 209                      0.5                                       NaN
# 210                      0.4                                      9.31
# 211                      0.3                                     40.47
# 212                      0.7                                     99.43
#
#     Total excluding LUCF
# 1               35247.21
# 2                    NaN
# 3                    NaN
# 4                   7.44
# 5                   5.56
# ..                   ...
# 208               257.86
# 209                  NaN
# 210                 9.31
# 211                 7.74
# 212                12.27
#
# [212 rows x 10 columns]

# %%
dados_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 1 to 212
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    212 non-null    object
#  1   Fossil CO2 emissions(Mt CO2) 1990          212 non-null    float64
#  2   2005                                       212 non-null    float64
#  3   2017                                       212 non-null    float64
#  4   Fossil CO2 emissions (2017(% of world))    212 non-null    object
#  5   2017 vs 1990: change (%)                   212 non-null    object
#  6   2017  Fossil CO2 emissions                 210 non-null    object
#  7   Per capita(t CO2/cap/yr)                   210 non-null    object
#  8   2018 CO2 emissions (Total including LUCF)  185 non-null    object
#  9   Total excluding LUCF                       184 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 16.7+ KB

# %%
dadosdf = dados_.drop([1,2,3]).reset_index(drop=True)
dadosdf
# Out:
#             Country  Fossil CO2 emissions(Mt CO2) 1990    2005     2017  \
# 0       Afghanistan                              2.546   1.063   11.422
# 1           Albania                              6.583   4.196    5.026
# 2           Algeria                             65.677  98.197  159.929
# 3            Angola                              5.851  15.975   30.876
# 4          Anguilla                              0.006   0.014    0.028
# ..              ...                                ...     ...      ...
# 204         Vietnam                             20.182  99.231  218.729
# 205  Western Sahara                              0.144   0.227    0.276
# 206           Yemen                              6.887  21.768   12.503
# 207          Zambia                              2.955   2.457    4.967
# 208        Zimbabwe                             17.178  11.388   12.087
#
#     Fossil CO2 emissions (2017(% of world)) 2017 vs 1990: change (%)  \
# 0                                     0.03%                  348.60%
# 1                                     0.01%                  -23.70%
# 2                                     0.43%                  143.50%
# 3                                     0.08%                  427.70%
# 4                                     0.00%                  366.70%
# ..                                      ...                      ...
# 204                                   0.59%                  983.80%
# 205                                   0.00%                   91.70%
# 206                                   0.03%                   81.50%
# 207                                   0.01%                   68.10%
# 208                                   0.03%                  -29.60%
#
#     2017  Fossil CO2 emissions Per capita(t CO2/cap/yr)  \
# 0                           18                      0.3
# 1                          175                      1.7
# 2                           67                      3.9
# 3                           25                        1
# 4                          308                      1.9
# ..                         ...                      ...
# 204                        660                      2.3
# 205                          1                      0.5
# 206                         24                      0.4
# 207                          7                      0.3
# 208                         31                      0.7
#
#     2018 CO2 emissions (Total including LUCF) Total excluding LUCF
# 0                                        7.59                 7.44
# 1                                        5.32                 5.56
# 2                                      151.87               151.67
# 3                                       62.93                27.34
# 4                                         NaN                  NaN
# ..                                        ...                  ...
# 204                                    245.36               257.86
# 205                                       NaN                  NaN
# 206                                      9.31                 9.31
# 207                                     40.47                 7.74
# 208                                     99.43                12.27
#
# [209 rows x 10 columns]

# %%
dadosdf['Fossil CO2 emissions(Mt CO2) 1990'].plot()
# Out:
# <AxesSubplot: >

# %%
emissao_com_mais_de_cemvinte_k = dadosdf[dadosdf['Fossil CO2 emissions(Mt CO2) 1990'] >= 120.000]
emissao_com_mais_de_cemvinte_k.head()
# Out:
#            Country  Fossil CO2 emissions(Mt CO2) 1990      2005       2017  \
# 9        Australia                            275.408   391.590    402.253
# 25          Brazil                            228.603   380.765    492.791
# 33          Canada                            455.827   581.267    617.301
# 39           China                           2397.048  6263.064  10877.218
# 49  Czech Republic                            162.835   127.157    109.756
#
#    Fossil CO2 emissions (2017(% of world)) 2017 vs 1990: change (%)  \
# 9                                    1.08%                   46.10%
# 25                                   1.33%                  115.60%
# 33                                   1.66%                   35.40%
# 39                                  29.34%                  353.80%
# 49                                   0.30%                  -32.60%
#
#    2017  Fossil CO2 emissions Per capita(t CO2/cap/yr)  \
# 9                          52                     16.5
# 25                         58                      2.4
# 33                         62                     16.9
# 39                       1133                      7.7
# 49                       1392                     10.3
#
#    2018 CO2 emissions (Total including LUCF) Total excluding LUCF
# 9                                     388.81               386.62
# 25                                    812.02               427.71
# 33                                    609.67                574.4
# 39                                   9663.36             10313.46
# 49                                     96.66               102.48

# %%
emissao_com_mais_de_cemvinte_k = emissao_com_mais_de_cemvinte_k.sort_values('Fossil CO2 emissions(Mt CO2) 1990', ascending=False)

# %%
plt.bar(emissao_com_mais_de_cemvinte_k['Country'], emissao_com_mais_de_cemvinte_k['Fossil CO2 emissions(Mt CO2) 1990'])
plt.xticks(rotation=90);
